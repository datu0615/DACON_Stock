# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
path = '/content/drive/MyDrive/stock_2/prophet/'
sub1 = pd.read_csv(path + 'neural_prophet_lag_5.csv')
sub2 = pd.read_csv(path + 'neural_prophet_lag_20.csv')
sub3 = pd.read_csv(path + 'neural_prophet_lag_60.csv')
sub4 = pd.read_csv(path + 'neural_prophet_lag_120.csv')

# %%
sub = sub1.copy()
sub.iloc[:,1:] = sub1.iloc[:,1:]*0.4 + sub2.iloc[:,1:] * 0.3 + sub3.iloc[:,1:] * 0.2 + sub3.iloc[:,1:] * 0.1

# %%
sub.to_csv(path + 'prophet_ensemble_reverse.csv', index=False)
